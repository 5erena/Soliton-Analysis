# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
## Analytical Speed
# 100 linearly spaced numbers
a = np.linspace(1^5,500,100)

# %%
# the function
c = (2*a**2*np.log(a)-a**2+1)/(a-1)**2

# %%
# setting the axes at the centre
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# %%
# plot the function
plt.plot(a,c, 'r', label=r'$c(a)=\frac{2a^2\ln(a)-a^2+1}{(a-1)^2}$')
plt.legend(loc='lower right', prop={'size': 16})
plt.xlabel('Amplitude (dimensionless)')
plt.ylabel('Speed (dimensionless)')
# Out:
# Text(0, 0.5, 'Speed (dimensionless)')

# %%
from os.path import dirname, join as pjoin
import scipy.io as sio
from scipy.io import loadmat

# %%
data7=loadmat('Experimental_data_soliton_project/expData07.mat',squeeze_me=False)

# %%
plt.imshow(data7['Amat'], origin='lower', aspect='auto')

# %%
## First experiment
data7['Amat']
# Out:
# array([[1.29883487, 1.28420023, 1.07997691, ..., 1.22934478, 1.2407938 ,
#         1.2551797 ],
#        [1.21227076, 1.04809743, 1.02450125, ..., 1.22079285, 1.2407938 ,
#         1.2551797 ],
#        [1.29883487, 1.29883487, 1.30765546, ..., 1.22079285, 1.22649082,
#         1.2551797 ],
#        ...,
#        [5.1953395 , 4.9631752 , 4.76438452, ..., 1.23792657, 1.2551797 ,
#         1.21227076],
#        [5.1953395 , 4.9631752 , 4.64706029, ..., 1.30324144, 1.29883487,
#         1.29883487],
#        [3.8819529 , 4.08758413, 4.22409011, ..., 2.04321166, 1.84574763,
#         1.82829385]])

# %%
len(data7['Amat']) #rows
# Out:
# 227

# %%
len(data7['Amat'][0]) #columns
# Out:
# 4418

# %%
z = np.amax(data7['Amat'], axis=0)

# %%
print('Max value of every column: ', z)
# Out:
# Max value of every column:  [5.28376922 5.25420973 5.14263986 ... 2.04321166 1.84574763 1.82829385]

# %%
t = np.argmax(data7['Amat'], axis=0)

# %%
print('List of Indices of maximum element :', t)
# Out:
# List of Indices of maximum element : [ 93 109 153 ... 226 226 226]

# %%
w = np.linspace(0,len(z),len(z))

# %%
plt.plot(w,t)

# %%
m, b = np.polyfit(w[1000:3000], t[1000:3000], 1)

# %%
plt.plot(w, t, '-')
plt.plot(w, m*w + b)
plt.legend(["Experimental Data", "Line of best fit"])

# %%
plt.imshow(data7['Amat'], origin='lower', aspect='auto')
plt.plot(w, m*w + b, color='red')

# %%
m
# Out:
# 0.039695076539771855

# %%
slopes = []

# %%
slopes.append(m)

# %% [markdown]
# ## nth experiment

# %%
data48=loadmat('Experimental_data_soliton_project/expData48.mat',squeeze_me=False)
plt.imshow(data48['Amat'], origin='lower', aspect='auto')

# %%
#print('Matrix is size', len(data19['Amat']), 'rows x', len(data19['Amat'][0]), 'columns')

# %%
z = np.amax(data48['Amat'], axis=0)
t = np.argmax(data48['Amat'], axis=0)
w = np.linspace(0,len(z),len(z))

plt.plot(w,t)
m, b = np.polyfit(w[1000:3000], t[1000:3000], 1)

plt.imshow(data48['Amat'], origin='lower', aspect='auto')
plt.plot(w, m*w + b, color='red')

# %%
print(m)
slopes.append(m)
# Out:
# 0.020205077831441893

# %%
slopes
# Out:
# [0.039695076539771855,
#  0.04882605483773824,
#  0.04569829842344287,
#  0.05211178852579685,
#  0.03788733298942377,
#  0.028203725644297618,
#  0.028245288002802463,
#  0.044540431708506495,
#  0.041248989526794455,
#  0.03461186081725688,
#  0.03372538813256293,
#  0.0313288201943047,
#  0.02970707948104033,
#  0.030229884479327583,
#  0.029454282657313244,
#  0.024519692798979767,
#  0.02535536144267738,
#  0.032921917309348396,
#  0.029459324921653908,
#  0.025336244275027783,
#  0.02469115411818458,
#  0.0227879090971258,
#  0.021520820612743737,
#  0.021752280567371964,
#  0.019902951059680447,
#  0.02015366863793317,
#  0.02133893107213396,
#  0.032448819999215665,
#  0.036143855495779996,
#  0.02800689369979655,
#  0.029207488431417558,
#  0.02802394314314473,
#  0.03017532750409285,
#  0.02139304379317787,
#  0.02210091795523543,
#  0.020953871921392395,
#  0.02065654944918687,
#  0.021834170717450058,
#  0.020205077831441893]
